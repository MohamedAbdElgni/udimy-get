# %%
import json
import requests
import base64

with open("conf.json", "r") as config_file:
    config = json.load(config_file)

client_id = config["client_id"]
client_secret = config["client_secret"]

# %%
# Replace with your actual client ID and client secret

# Base URL for Udemy Affiliate API
base_url = "https://www.udemy.com/api-2.0/"

# Endpoint for courses
courses_endpoint = "courses/"

# Create the authentication header with base64-encoded client ID and client secret
auth_string = f"{client_id}:{client_secret}"
auth_header = base64.b64encode(auth_string.encode()).decode("utf-8")

# Add the Authorization header to the request
headers = {"Authorization": f"Basic {auth_header}"}

# Make a GET request to retrieve course data
response = requests.get(base_url + courses_endpoint, headers=headers)

# Check if the request was successful (HTTP status code 200)
if response.status_code == 200:
    course_data = response.json()
    # You now have the course data in the course_data variable
    # now we ptint it in organized way

    print(json.dumps(course_data['results'], indent=4, sort_keys=True))
# Out:
# [
#     {
#         "_class": "course",
#         "curriculum_items": [],
#         "curriculum_lectures": [],
#         "headline": "Learn web design in 1 hour with 25+ simple-to-use rules and guidelines \u2014 tons of amazing web design resources included!",
#         "id": 473160,
#         "image_125_H": "https://img-c.udemycdn.com/course/125_H/473160_d929_3.jpg",
#         "image_240x135": "https://img-c.udemycdn.com/course/240x135/473160_d929_3.jpg",
#         "image_480x270": "https://img-c.udemycdn.com/course/480x270/473160_d929_3.jpg",
#         "input_features": null,
#         "instructor_name": null,
#         "is_paid": false,
#         "is_practice_test_course": false,
#         "lecture_search_result": null,
#         "locale": {
#             "_class": "locale",
#             "english_title": "English (US)",
#             "locale": "en_US",
#             "simple_english_title": "English",
#             "title": "English (US)"
#         },
#         "order_in_results": null,
#         "predictive_score": null,
#         "price": "Free",
#         "price_detail": null,
#         "price_serve_tracking_id": "0xRSvhbbR9WRgTF0xDMmEA",
#         "published_title": "web-design-secrets",
#         "relevancy_score": null,
#         "title": "Web Design for Web Developers: Build Beautiful Websites!",
#         "tracking_id": "",
#         "url": "/course/web-design-secrets/",
#         "visible_instructors": [
#             {
#                 "_class": "user",
#                 "display_name": "Jonas Schmedtmann",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/7799204_2091_5.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/7799204_2091_5.jpg",
#                 "initials": "JS",
#                 "job_title": "Web Developer, Designer, and Teacher",
#                 "name": "Jonas",
#                 "title": "Jonas Schmedtmann",
#                 "url": "/user/jonasschmedtmann/"
#             }
#         ]
#     },
#     {
#         "_class": "course",
#         "curriculum_items": [],
#         "curriculum_lectures": [],
#         "headline": "In just 2 hours supercharge your ChatGPT skills with plugins, the code interpreter, and prompt engineering!",
#         "id": 5512420,
#         "image_125_H": "https://img-c.udemycdn.com/course/125_H/5512420_3119_2.jpg",
#         "image_240x135": "https://img-c.udemycdn.com/course/240x135/5512420_3119_2.jpg",
#         "image_480x270": "https://img-c.udemycdn.com/course/480x270/5512420_3119_2.jpg",
#         "input_features": null,
#         "instructor_name": null,
#         "is_paid": false,
#         "is_practice_test_course": false,
#         "lecture_search_result": null,
#         "locale": {
#             "_class": "locale",
#             "english_title": "English (US)",
#             "locale": "en_US",
#             "simple_english_title": "English",
#             "title": "English (US)"
#         },
#         "order_in_results": null,
#         "predictive_score": null,
#         "price": "Free",
#         "price_detail": null,
#         "price_serve_tracking_id": "LoszjwKzTve-wqMRfmVyNw",
#         "published_title": "chatgpt-quick-guide-prompt-engineering-plugins-and-more",
#         "relevancy_score": null,
#         "title": "ChatGPT Quick Guide - Prompt Engineering, Plugins, and more!",
#         "tracking_id": "",
#         "url": "/course/chatgpt-quick-guide-prompt-engineering-plugins-and-more/",
#         "visible_instructors": [
#             {
#                 "_class": "user",
#                 "display_name": "Jose Portilla",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/9685726_67e7_4.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/9685726_67e7_4.jpg",
#                 "initials": "JP",
#                 "job_title": "Head of Data Science at Pierian Training",
#                 "name": "Jose",
#                 "title": "Jose Portilla",
#                 "url": "/user/joseportilla/"
#             }
#         ]
#     },
#     {
#         "_class": "course",
#         "curriculum_items": [],
#         "curriculum_lectures": [],
#         "headline": "Learn to program using the Java programming language",
#         "id": 24823,
#         "image_125_H": "https://img-c.udemycdn.com/course/125_H/24823_963e_14.jpg",
#         "image_240x135": "https://img-c.udemycdn.com/course/240x135/24823_963e_14.jpg",
#         "image_480x270": "https://img-c.udemycdn.com/course/480x270/24823_963e_14.jpg",
#         "input_features": null,
#         "instructor_name": null,
#         "is_paid": false,
#         "is_practice_test_course": false,
#         "lecture_search_result": null,
#         "locale": {
#             "_class": "locale",
#             "english_title": "English (UK)",
#             "locale": "en_GB",
#             "simple_english_title": "English",
#             "title": "English (UK)"
#         },
#         "order_in_results": null,
#         "predictive_score": null,
#         "price": "Free",
#         "price_detail": null,
#         "price_serve_tracking_id": "GrbiWn8OTfOUfgjXEiuVZQ",
#         "published_title": "java-tutorial",
#         "relevancy_score": null,
#         "title": "Java Tutorial for Complete Beginners",
#         "tracking_id": "",
#         "url": "/course/java-tutorial/",
#         "visible_instructors": [
#             {
#                 "_class": "user",
#                 "display_name": "John Purcell",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/219513_a344_6.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/219513_a344_6.jpg",
#                 "initials": "JP",
#                 "job_title": "Software Development Trainer",
#                 "name": "John",
#                 "title": "John Purcell",
#                 "url": "/user/johnpurcell/"
#             }
#         ]
#     },
#     {
#         "_class": "course",
#         "curriculum_items": [],
#         "curriculum_lectures": [],
#         "headline": "A Quick and Easy Intro to Python Programming",
#         "id": 433798,
#         "image_125_H": "https://img-c.udemycdn.com/course/125_H/433798_1de9_4.jpg",
#         "image_240x135": "https://img-c.udemycdn.com/course/240x135/433798_1de9_4.jpg",
#         "image_480x270": "https://img-c.udemycdn.com/course/480x270/433798_1de9_4.jpg",
#         "input_features": null,
#         "instructor_name": null,
#         "is_paid": false,
#         "is_practice_test_course": false,
#         "lecture_search_result": null,
#         "locale": {
#             "_class": "locale",
#             "english_title": "English (US)",
#             "locale": "en_US",
#             "simple_english_title": "English",
#             "title": "English (US)"
#         },
#         "order_in_results": null,
#         "predictive_score": null,
#         "price": "Free",
#         "price_detail": null,
#         "price_serve_tracking_id": "HtwuLZVJQ1ymgvnkdr08rw",
#         "published_title": "pythonforbeginnersintro",
#         "relevancy_score": null,
#         "title": "Introduction To Python Programming",
#         "tracking_id": "",
#         "url": "/course/pythonforbeginnersintro/",
#         "visible_instructors": [
#             {
#                 "_class": "user",
#                 "display_name": "Avinash Jain",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/10260436_946b_6.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/10260436_946b_6.jpg",
#                 "initials": "AJ",
#                 "job_title": "Founder @ The Codex",
#                 "name": "Avinash",
#                 "title": "Avinash Jain",
#                 "url": "/user/avinashjain5/"
#             },
#             {
#                 "_class": "user",
#                 "display_name": "The Codex",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/52310762_220a.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/52310762_220a.jpg",
#                 "initials": "TC",
#                 "job_title": "Teaching Python through Projects",
#                 "name": "The",
#                 "title": "The Codex",
#                 "url": "/user/thecodex/"
#             }
#         ]
#     },
#     {
#         "_class": "course",
#         "curriculum_items": [],
#         "curriculum_lectures": [],
#         "headline": "Learn the basics of Microsoft Excel and become an effective user",
#         "id": 53600,
#         "image_125_H": "https://img-c.udemycdn.com/course/125_H/53600_553c_4.jpg",
#         "image_240x135": "https://img-c.udemycdn.com/course/240x135/53600_553c_4.jpg",
#         "image_480x270": "https://img-c.udemycdn.com/course/480x270/53600_553c_4.jpg",
#         "input_features": null,
#         "instructor_name": null,
#         "is_paid": false,
#         "is_practice_test_course": false,
#         "lecture_search_result": null,
#         "locale": {
#             "_class": "locale",
#             "english_title": "English (India)",
#             "locale": "en_IN",
#             "simple_english_title": "English",
#             "title": "English (India)"
#         },
#         "order_in_results": null,
#         "predictive_score": null,
#         "price": "Free",
#         "price_detail": null,
#         "price_serve_tracking_id": "7JdhYKp4S2W4J0BV3KM9Uw",
#         "published_title": "useful-excel-for-beginners",
#         "relevancy_score": null,
#         "title": "Useful Excel for Beginners",
#         "tracking_id": "",
#         "url": "/course/useful-excel-for-beginners/",
#         "visible_instructors": [
#             {
#                 "_class": "user",
#                 "display_name": "Dinesh Natarajan Mohan",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/766769_faf7_6.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/766769_faf7_6.jpg",
#                 "initials": "DN",
#                 "job_title": "Sharing simple but effective solutions",
#                 "name": "Dinesh",
#                 "title": "Dinesh Natarajan Mohan",
#                 "url": "/user/indzara/"
#             }
#         ]
#     },
#     {
#         "_class": "course",
#         "curriculum_items": [],
#         "curriculum_lectures": [],
#         "headline": "A step by step introduction to the concept of Databases and Introduction to SQL Querying.",
#         "id": 552672,
#         "image_125_H": "https://img-c.udemycdn.com/course/125_H/552672_e2b6_5.jpg",
#         "image_240x135": "https://img-c.udemycdn.com/course/240x135/552672_e2b6_5.jpg",
#         "image_480x270": "https://img-c.udemycdn.com/course/480x270/552672_e2b6_5.jpg",
#         "input_features": null,
#         "instructor_name": null,
#         "is_paid": false,
#         "is_practice_test_course": false,
#         "lecture_search_result": null,
#         "locale": {
#             "_class": "locale",
#             "english_title": "English (US)",
#             "locale": "en_US",
#             "simple_english_title": "English",
#             "title": "English (US)"
#         },
#         "order_in_results": null,
#         "predictive_score": null,
#         "price": "Free",
#         "price_detail": null,
#         "price_serve_tracking_id": "swGlMP2HTLSe9_Z_Qs81kQ",
#         "published_title": "introduction-to-databases-and-sql-querying",
#         "relevancy_score": null,
#         "title": "Introduction to Databases and SQL Querying",
#         "tracking_id": "",
#         "url": "/course/introduction-to-databases-and-sql-querying/",
#         "visible_instructors": [
#             {
#                 "_class": "user",
#                 "display_name": "Rakesh Gopalakrishnan",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/9912714_deb0_2.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/9912714_deb0_2.jpg",
#                 "initials": "RG",
#                 "job_title": "Over 600,000 Students",
#                 "name": "Rakesh",
#                 "title": "Rakesh Gopalakrishnan",
#                 "url": "/user/54a6020bb2e0e/"
#             }
#         ]
#     },
#     {
#         "_class": "course",
#         "curriculum_items": [],
#         "curriculum_lectures": [],
#         "headline": "How to program in the popular (and tricky!) C++ programming language, for complete beginners.",
#         "id": 247190,
#         "image_125_H": "https://img-c.udemycdn.com/course/125_H/247190_5cb0_2.jpg",
#         "image_240x135": "https://img-c.udemycdn.com/course/240x135/247190_5cb0_2.jpg",
#         "image_480x270": "https://img-c.udemycdn.com/course/480x270/247190_5cb0_2.jpg",
#         "input_features": null,
#         "instructor_name": null,
#         "is_paid": false,
#         "is_practice_test_course": false,
#         "lecture_search_result": null,
#         "locale": {
#             "_class": "locale",
#             "english_title": "English (UK)",
#             "locale": "en_GB",
#             "simple_english_title": "English",
#             "title": "English (UK)"
#         },
#         "order_in_results": null,
#         "predictive_score": null,
#         "price": "Free",
#         "price_detail": null,
#         "price_serve_tracking_id": "C-XkoPAdT8u2_sQr8-ZAVA",
#         "published_title": "free-learn-c-tutorial-beginners",
#         "relevancy_score": null,
#         "title": "C++ Tutorial for Complete Beginners",
#         "tracking_id": "",
#         "url": "/course/free-learn-c-tutorial-beginners/",
#         "visible_instructors": [
#             {
#                 "_class": "user",
#                 "display_name": "John Purcell",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/219513_a344_6.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/219513_a344_6.jpg",
#                 "initials": "JP",
#                 "job_title": "Software Development Trainer",
#                 "name": "John",
#                 "title": "John Purcell",
#                 "url": "/user/johnpurcell/"
#             }
#         ]
#     },
#     {
#         "_class": "course",
#         "curriculum_items": [],
#         "curriculum_lectures": [],
#         "headline": "Beginners, Zero to Hero. AWS EC2 web server, NodeJS Server, AWS RDS database server, S3, SES & CloudWatch. FREE",
#         "id": 1331946,
#         "image_125_H": "https://img-c.udemycdn.com/course/125_H/1331946_ed41_4.jpg",
#         "image_240x135": "https://img-c.udemycdn.com/course/240x135/1331946_ed41_4.jpg",
#         "image_480x270": "https://img-c.udemycdn.com/course/480x270/1331946_ed41_4.jpg",
#         "input_features": null,
#         "instructor_name": null,
#         "is_paid": false,
#         "is_practice_test_course": false,
#         "lecture_search_result": null,
#         "locale": {
#             "_class": "locale",
#             "english_title": "English (US)",
#             "locale": "en_US",
#             "simple_english_title": "English",
#             "title": "English (US)"
#         },
#         "order_in_results": null,
#         "predictive_score": null,
#         "price": "Free",
#         "price_detail": null,
#         "price_serve_tracking_id": "cTRxQm4ERwaX1ZYQFJiFJw",
#         "published_title": "amazon-web-services-aws-v",
#         "relevancy_score": null,
#         "title": "Amazon Web Services (AWS) - Zero to Hero",
#         "tracking_id": "",
#         "url": "/course/amazon-web-services-aws-v/",
#         "visible_instructors": [
#             {
#                 "_class": "user",
#                 "display_name": "BackSpace Academy",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/27829848_1d83.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/27829848_1d83.jpg",
#                 "initials": "BA",
#                 "job_title": "The fastest route to cloud certification.",
#                 "name": "BackSpace",
#                 "title": "BackSpace Academy",
#                 "url": "/user/backspace-academy/"
#             }
#         ]
#     },
#     {
#         "_class": "course",
#         "curriculum_items": [],
#         "curriculum_lectures": [],
#         "headline": "Discover learning best practices, including setting goals, practicing & applying, reflecting, and learning with others.",
#         "id": 3633804,
#         "image_125_H": "https://img-c.udemycdn.com/course/125_H/3633804_2d54_2.jpg",
#         "image_240x135": "https://img-c.udemycdn.com/course/240x135/3633804_2d54_2.jpg",
#         "image_480x270": "https://img-c.udemycdn.com/course/480x270/3633804_2d54_2.jpg",
#         "input_features": null,
#         "instructor_name": null,
#         "is_paid": false,
#         "is_practice_test_course": false,
#         "lecture_search_result": null,
#         "locale": {
#             "_class": "locale",
#             "english_title": "English (US)",
#             "locale": "en_US",
#             "simple_english_title": "English",
#             "title": "English (US)"
#         },
#         "order_in_results": null,
#         "predictive_score": null,
#         "price": "Free",
#         "price_detail": null,
#         "price_serve_tracking_id": "wkL8_iUHRICj1zxrNDAM2g",
#         "published_title": "how-to-learn-effective-approaches-for-self-guided-learning",
#         "relevancy_score": null,
#         "title": "How to Learn: Effective Approaches for Self-Guided Learning",
#         "tracking_id": "",
#         "url": "/course/how-to-learn-effective-approaches-for-self-guided-learning/",
#         "visible_instructors": [
#             {
#                 "_class": "user",
#                 "display_name": "Udemy Learning Team",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/124095718_f0cc_9.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/124095718_f0cc_9.jpg",
#                 "initials": "UT",
#                 "job_title": "Udemy Learning Team",
#                 "name": "Udemy Learning",
#                 "title": "Udemy Learning Team",
#                 "url": "/user/svc-ld-team/"
#             },
#             {
#                 "_class": "user",
#                 "display_name": "Padraig Nash",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/111614824_961e.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/111614824_961e.jpg",
#                 "initials": "PN",
#                 "job_title": "Director of Learning Science and Instructional Design",
#                 "name": "Padraig",
#                 "title": "Padraig Nash",
#                 "url": "/user/padraig-nash/"
#             }
#         ]
#     },
#     {
#         "_class": "course",
#         "curriculum_items": [],
#         "curriculum_lectures": [],
#         "headline": "Learn to quickly connect with crowds of strangers, be better on dates or ace that job interview.",
#         "id": 780078,
#         "image_125_H": "https://img-c.udemycdn.com/course/125_H/780078_e409_2.jpg",
#         "image_240x135": "https://img-c.udemycdn.com/course/240x135/780078_e409_2.jpg",
#         "image_480x270": "https://img-c.udemycdn.com/course/480x270/780078_e409_2.jpg",
#         "input_features": null,
#         "instructor_name": null,
#         "is_paid": false,
#         "is_practice_test_course": false,
#         "lecture_search_result": null,
#         "locale": {
#             "_class": "locale",
#             "english_title": "English (US)",
#             "locale": "en_US",
#             "simple_english_title": "English",
#             "title": "English (US)"
#         },
#         "order_in_results": null,
#         "predictive_score": null,
#         "price": "Free",
#         "price_detail": null,
#         "price_serve_tracking_id": "ZCHlVAYsSJqCN93cMr0ydQ",
#         "published_title": "fearless-public-speaker-bootcamp-by-ricky-mendoza",
#         "relevancy_score": null,
#         "title": "How to speak to anyone & be fearless - in less than 55 min",
#         "tracking_id": "",
#         "url": "/course/fearless-public-speaker-bootcamp-by-ricky-mendoza/",
#         "visible_instructors": [
#             {
#                 "_class": "user",
#                 "display_name": "Ricardo Mendoza",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/8678100_c955_2.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/8678100_c955_2.jpg",
#                 "initials": "RM",
#                 "job_title": "Founder of Digital Work Studios and Interpretap",
#                 "name": "Ricardo",
#                 "title": "Ricardo Mendoza",
#                 "url": "/user/ricardomendoza9/"
#             }
#         ]
#     },
#     {
#         "_class": "course",
#         "curriculum_items": [],
#         "curriculum_lectures": [],
#         "headline": "7 steps you can use immediately to become more productive and master time management",
#         "id": 797156,
#         "image_125_H": "https://img-c.udemycdn.com/course/125_H/797156_d7dd_5.jpg",
#         "image_240x135": "https://img-c.udemycdn.com/course/240x135/797156_d7dd_5.jpg",
#         "image_480x270": "https://img-c.udemycdn.com/course/480x270/797156_d7dd_5.jpg",
#         "input_features": null,
#         "instructor_name": null,
#         "is_paid": false,
#         "is_practice_test_course": false,
#         "lecture_search_result": null,
#         "locale": {
#             "_class": "locale",
#             "english_title": "English (US)",
#             "locale": "en_US",
#             "simple_english_title": "English",
#             "title": "English (US)"
#         },
#         "order_in_results": null,
#         "predictive_score": null,
#         "price": "Free",
#         "price_detail": null,
#         "price_serve_tracking_id": "nahc9aoXS-y94TR9LeZtrQ",
#         "published_title": "manageyourtime",
#         "relevancy_score": null,
#         "title": "A Mini Course on Time Management",
#         "tracking_id": "",
#         "url": "/course/manageyourtime/",
#         "visible_instructors": [
#             {
#                 "_class": "user",
#                 "display_name": "Brandon Hakim",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/9304596_0ac3_7.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/9304596_0ac3_7.jpg",
#                 "initials": "BH",
#                 "job_title": "Founder of InsiderSchool",
#                 "name": "Brandon",
#                 "title": "Brandon Hakim",
#                 "url": "/user/brandonhakim/"
#             },
#             {
#                 "_class": "user",
#                 "display_name": "Insider School",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/129334448_b32a_3.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/129334448_b32a_3.jpg",
#                 "initials": "IS",
#                 "job_title": "Change Your Life In 5 Minutes A Day",
#                 "name": "Insider",
#                 "title": "Insider School",
#                 "url": "/user/insider-school/"
#             }
#         ]
#     },
#     {
#         "_class": "course",
#         "curriculum_items": [],
#         "curriculum_lectures": [],
#         "headline": "Learn AI Tools in just 15 minutes. Start using ChatGPT, Midjourney, Google Bard, Adobe Firefly and DALL-E today!",
#         "id": 5322038,
#         "image_125_H": "https://img-c.udemycdn.com/course/125_H/5322038_1954.jpg",
#         "image_240x135": "https://img-c.udemycdn.com/course/240x135/5322038_1954.jpg",
#         "image_480x270": "https://img-c.udemycdn.com/course/480x270/5322038_1954.jpg",
#         "input_features": null,
#         "instructor_name": null,
#         "is_paid": false,
#         "is_practice_test_course": false,
#         "lecture_search_result": null,
#         "locale": {
#             "_class": "locale",
#             "english_title": "English (US)",
#             "locale": "en_US",
#             "simple_english_title": "English",
#             "title": "English (US)"
#         },
#         "order_in_results": null,
#         "predictive_score": null,
#         "price": "Free",
#         "price_detail": null,
#         "price_serve_tracking_id": "VZSo_B5MTx-yp8Mn06Ar9A",
#         "published_title": "chatgpt-midjourney-google-bard-dall-e-ai-course",
#         "relevancy_score": null,
#         "title": "ChatGPT, Midjourney, Firefly, Bard, DALL-E, AI Crash Course",
#         "tracking_id": "",
#         "url": "/course/chatgpt-midjourney-google-bard-dall-e-ai-course/",
#         "visible_instructors": [
#             {
#                 "_class": "user",
#                 "display_name": "Phil Ebiner",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/317821_3cb5_10.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/317821_3cb5_10.jpg",
#                 "initials": "PE",
#                 "job_title": "Top-Rated Instructor, 2.5 Million+ Students",
#                 "name": "Phil",
#                 "title": "Phil Ebiner",
#                 "url": "/user/philipebiner2/"
#             },
#             {
#                 "_class": "user",
#                 "display_name": "Video School",
#                 "image_100x100": "https://img-b.udemycdn.com/user/100x100/19701574_95d1_13.jpg",
#                 "image_50x50": "https://img-b.udemycdn.com/user/50x50/19701574_95d1_13.jpg",
#                 "initials": "VS",
#                 "job_title": "Learn Creative Skills",
#                 "name": "Video",
#                 "title": "Video School",
#                 "url": "/user/phil-ebiner/"
#             }
#         ]
#     }
# ]
